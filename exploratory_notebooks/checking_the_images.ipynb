# %%
import pyforest

# %%
import SimpleITK as sitk
import numpy as np
import matplotlib.pyplot as plt

# %%
itkimage = sitk.ReadImage("../data/RETOUCH-TrainingSet-Cirrus/TRAIN001/oct.mhd")
oct_scan = sitk.GetArrayFromImage(itkimage)
for i in range(8):
    plt.figure(figsize=(5,15))
    plt.imshow(oct_scan[10*i,:,:])
    plt.show()

# %%
itkimage = sitk.ReadImage("../data/RETOUCH-TrainingSet-Cirrus/TRAIN001/reference.mhd")
oct_scan = sitk.GetArrayFromImage(itkimage)
for i in range(10):
    plt.figure()
    plt.imshow(oct_scan[10*i,:,:])
    plt.show()
